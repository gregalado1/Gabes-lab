# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('HY_Universe_corporate bond.csv')
df.drop(['CUSIP', '1st Call Date'],axis=1,inplace=True)

# %%
row_count=df.shape[0]
column_count = df.shape[1]
print(f'The number of rows is {row_count}, while the number of columns is {column_count}.')
# Out:
# The number of rows is 2721, while the number of columns is 35.

# %%
df.describe()
# Out:
#             Coupon  Issued Amount  Maturity At Issue months  LiquidityScore  \
# count  2721.000000   2.721000e+03               2721.000000     2721.000000
# mean     10.307872   8.299295e+08                113.968997       18.218230
# std      63.051382   5.802790e+08                101.893176        7.872071
# min       0.000000   3.700000e+08                 11.930000        4.388758
# 25%       5.000000   5.000000e+08                 65.170000       12.738630
# 50%       6.250000   6.500000e+08                 97.370000       16.538471
# 75%       7.750000   1.000000e+09                121.770000       22.120108
# max     999.000000   7.364026e+09               1217.570000       54.673908
#
#          LIQ SCORE      n_trades  volume_trades  total_median_size  \
# count  2721.000000   2721.000000   2.721000e+03       2.721000e+03
# mean      0.182182   2700.696435   7.222372e+08       5.361476e+05
# std       0.078721   5572.262205   1.027825e+09       4.193546e+05
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2721 entries, 0 to 2720
# Data columns (total 35 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Ticker                      2721 non-null   object
#  1   Issue Date                  2721 non-null   object
#  2   Maturity                    2721 non-null   object
#  3   Moodys                      2721 non-null   object
#  4   S_and_P                     2721 non-null   object
#  5   Fitch                       2721 non-null   object
#  6   Bloomberg Composite Rating  2721 non-null   object
#  7   Coupon                      2721 non-null   float64
#  8   Issued Amount               2721 non-null   float64
#  9   Maturity Type               2721 non-null   object
#  10  Coupon Type                 2721 non-null   object
#  11  Maturity At Issue months    2721 non-null   float64
#  12  Industry                    2721 non-null   object
# ...

# %%
# Look for missing values
df.isnull().sum()
# Out:
# Ticker                        0
# Issue Date                    0
# Maturity                      0
# Moodys                        0
# S_and_P                       0
# Fitch                         0
# Bloomberg Composite Rating    0
# Coupon                        0
# Issued Amount                 0
# Maturity Type                 0
# Coupon Type                   0
# Maturity At Issue months      0
# Industry                      0
# LiquidityScore                0
# Months in JNK                 0
# Months in HYG                 0
# Months in Both                0
# IN_ETF                        0
# LIQ SCORE                     0
# n_trades                      0
# volume_trades                 0
# total_median_size             0
# total_mean_size               0
# n_days_trade                  0
# days_diff_max                 0
# percent_intra_dealer          0
# percent_uncapped              0
# bond_type                     0
# Client_Trade_Percentage       0
# ...

# %%
df
# Out:
#       Ticker  Issue Date    Maturity Moodys S_and_P Fitch  \
# 0     FLECIN    7/1/2014    7/1/2019    Nan     Nan   Nan
# 1        RBS   3/15/2004    6/4/2018    Ba1     BB+   BBB
# 2       ACCO   5/14/2010   3/15/2015     WR      NR   BB+
# 3       ACCO   6/17/2013   4/30/2020     WR      NR    WD
# 4       ACCO  12/22/2016  12/15/2024     B1     BB-    BB
# ...      ...         ...         ...    ...     ...   ...
# 2716     NRG   4/18/2017   1/15/2027     B1     BB-   Nan
# 2717  NSGHLD   3/14/2007  12/15/2025    Ba1     BB+   Nan
# 2718    VMED   7/25/2006   8/15/2016     WR      NR   BB+
# 2719    NYLD    8/5/2014   8/15/2024    Ba2      BB   Nan
# 2720    NYLD   7/21/2015   8/15/2024    Ba2      BB   Nan
#
#      Bloomberg Composite Rating  Coupon  Issued Amount Maturity Type  ...  \
# 0                           Nan   12.00   4.050000e+08      CALLABLE  ...
# 1                           BB+    4.65   4.992850e+08   AT MATURITY  ...
# ...

# %%
import matplotlib.pyplot as plt
import statsmodels.api as sm
import pylab
import scipy.stats as stats
import seaborn as sns

# %%
df['Coupon'].size
# Out:
# 2721

# %%
measurements = df['Coupon']
stats.probplot(measurements, dist="norm", plot=pylab)
pylab.show()

# %%
df.corr()
# Out:
#                             Coupon  Issued Amount  Maturity At Issue months  \
# Coupon                    1.000000      -0.014238                  0.098844
# Issued Amount            -0.014238       1.000000                  0.008601
# Maturity At Issue months  0.098844       0.008601                  1.000000
# LiquidityScore           -0.042302       0.134930                  0.072507
# LIQ SCORE                -0.042302       0.134930                  0.072507
# n_trades                 -0.023330       0.156948                  0.038839
# volume_trades            -0.026717       0.326310                 -0.015227
# total_median_size         0.044601       0.062343                 -0.115086
# total_mean_size           0.026891       0.078362                 -0.138581
# n_days_trade             -0.028336       0.068113                  0.029530
# days_diff_max            -0.025089      -0.008097                  0.103178
# ...

# %%
df.corrwith(df["Coupon"])
#for specific target attributes
# Out:
# Coupon                      1.000000
# Issued Amount              -0.014238
# Maturity At Issue months    0.098844
# LiquidityScore             -0.042302
# LIQ SCORE                  -0.042302
# n_trades                   -0.023330
# volume_trades              -0.026717
# total_median_size           0.044601
# total_mean_size             0.026891
# n_days_trade               -0.028336
# days_diff_max              -0.025089
# percent_intra_dealer       -0.014316
# percent_uncapped           -0.045897
# bond_type                   0.051856
# Client_Trade_Percentage     0.029125
# weekly_mean_volume         -0.027724
# weekly_median_volume       -0.028584
# weekly_max_volume          -0.026362
# weekly_min_volume          -0.014438
# weekly_mean_ntrades        -0.028045
# weekly_median_ntrades      -0.018326
# dtype: float64

# %%
corr = df.corr()
sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns)
# Out:
# <AxesSubplot:>

# %%
sns.regplot(x=df['n_days_trade'], y=df['LIQ SCORE'])
# Out:
# <AxesSubplot:xlabel='n_days_trade', ylabel='LIQ SCORE'>

# %%
plt.style.use('bmh')

plt.scatter(x='Coupon', y='n_trades', data=df)
plt.ylabel('Coupon', fontsize=14)
plt.xlabel('number of trades', fontsize=14)
plt.show()

# %%
print("My name is Gabriel Regalado")
print("My NetID is: gregal2")
print("I hereby certify that I have read the University policy on Academic Integrity and that I am not in violation.")
# Out:
# My name is Gabriel Regalado
# My NetID is: gregal2
# I hereby certify that I have read the University policy on Academic Integrity and that I am not in violation.
